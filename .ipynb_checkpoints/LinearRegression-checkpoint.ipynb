# %%
# %run BankPreprocess.ipynb
# Out:
# /tmp/nix-shell.gEsIO6/ipykernel_153140/2410461767.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   base_df[col] = base_df[col].fillna(base_df[col].mean())
